# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.load_dataset('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df = sns.load_dataset('iris')

# %%
sns.displot(df.petal_length)

# %%
sns.relplot(data=df,x= "petal_length", y = "petal_width")

# %%
# 3. Would it be reasonable to predict species based on sepal width and sepal length? 
# For this, you'll visualize two numeric columns through the lense of a categorical column.

#sns.violinplot(data=df, x = "sepal_width", y = "sepal_length", hue="species")
sns.barplot(data=df, x = "sepal_width", y = "sepal_length", hue="species")
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %%
# 4. Which features would be best used to predict species?
# petal width and sepal length

sns.relplot(x='petal_width', y='sepal_length', hue="species", data=df)
plt.title("Petal length vs Sepal width")
# Out:
# Text(0.5, 1.0, 'Petal length vs Sepal width')

# %%
df2= sns.load_dataset('anscombe')

# %%
df2.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
df2.groupby('dataset').sum().plot(kind='bar', rot=45)
# Out:
# <Axes: xlabel='dataset'>

# %%
#rev_items = money.groupby('item_name')['price'].sum()
#price.agg('sum')

# %%
# 3. Load the swiss dataset from pydataset and read it's documentation. 
# Create visualizations to answer the following questions:

# %%
#merge
#chipolte.merge(pop_items, rev_items, left_on = 'item_name', right_on = 'item_name', how = 'inner')

#pop_and_rev = pd.merge(pop_items, rev_items, left_on = 'item_name', right_on = 'item_name', how = 'inner')
#sorted_chipotle = pop_and_rev.sort_values('quantity').nlargest(4).plot(kind = 'bar')

# %%
# !pip install pydataset
from pydataset import data

# %%
df3 = data('InsectSprays')

sns.boxplot(data=df3, y='count', x='spray')
plt.title('Effectiveness of Different Insect Sprays')
plt.xlabel('Insect Sprays')
plt.ylabel('Number of Observed Insects')
plt.show()

# %%
df4 = data('swiss')

df4.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality
# Courtelary                22.2
# Delemont                  22.2
# Franches-Mnt              20.2
# Moutier                   20.3
# Neuveville                20.6

# %%
df4['is_catholic'] = df4.Catholic > 9

# %%
df4.is_catholic
# Out:
# Courtelary       True
# Delemont         True
# Franches-Mnt     True
# Moutier          True
# Neuveville      False
# Porrentruy       True
# Broye            True
# Glane            True
# Gruyere          True
# Sarine           True
# Veveyse          True
# Aigle           False
# Aubonne         False
# Avenches        False
# Cossonay        False
# Echallens        True
# Grandson        False
# Lausanne         True
# La Vallee       False
# Lavaux          False
# Morges          False
# Moudon          False
# Nyone            True
# Orbe            False
# Oron            False
# Payerne         False
# Paysd'enhaut    False
# Rolle           False
# Vevey            True
# Yverdon         False
# Conthey          True
# Entremont        True
# Herens           True
# Martigwy         True
# Monthey          True
# St Maurice       True
# Sierre           True
# Sion             True
# Boudry          False
# La Chauxdfnd     True
# Le Locle         True
# ...

# %%
sns.histplot(df4, multiple='stack')
# Out:
# <Axes: ylabel='Count'>

# %%
sns.relplot(data=df4, x='Fertility', y='Catholic', hue='is_catholic')

# %%
sns.regplot(data=df4, x='Fertility', y='Agriculture')
# Out:
# <Axes: xlabel='Fertility', ylabel='Agriculture'>

# %%
sns.regplot(data=df4, x='Fertility', y='Examination', color='red')
# Out:
# <Axes: xlabel='Fertility', ylabel='Examination'>

# %%
sns.regplot(data=df4, x='Fertility', y='Education', scatter_kws={'alpha':0.3})
# Out:
# <Axes: xlabel='Fertility', ylabel='Education'>

# %%
sns.regplot(data=df4, x='Fertility', y='Catholic', scatter_kws={'alpha':0.3})
# Out:
# <Axes: xlabel='Fertility', ylabel='Catholic'>

# %%
sns.regplot(data=df4, x='Fertility', y='Infant.Mortality')
# Out:
# <Axes: xlabel='Fertility', ylabel='Infant.Mortality'>

# %%
import pymysql as pymy

# %%
import sqlalchemy

# %%
import env4

# %%
chipotle_sql_query = '''
                     SELECT *
                     FROM orders;
                     '''

# %%
orders = pd.read_sql(chipotle_sql_query, env4.get_db_url('chipotle'))
orders.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98

# %%
#orders.groupby('item_name')['quantity'].sum().nlargest(4)
pop_items = orders.groupby('item_name')['quantity'].sum()
#.nlargest()

# %%
pop_items
# Out:
# item_name
# 6 Pack Soft Drink                         55
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     12
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            211
# Bowl                                       4
# Burrito                                    6
# Canned Soda                              126
# Canned Soft Drink                        351
# Carnitas Bowl                             71
# Carnitas Burrito                          60
# Carnitas Crispy Tacos                      8
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chicken Crispy Tacos                      50
# Chicken Salad                              9
# ...

# %%
#orders.groupby(['item_name'])['price'].sum()
df5 = orders.groupby(['item_name', 'quantity']).agg([sum]).drop(['item_price', 'choice_description', 'order_id', 'id'], axis=1)
#pop_items = orders.groupby('item_name')['quantity'].sum()
#.nlargest()
review = orders.groupby('item_name')['price'].sum().nlargest(4)
# Out:
# /var/folders/p_/0z9srqwn3g11vvrv0s9wcxs40000gn/T/ipykernel_3925/3589283754.py:2: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df5 = orders.groupby(['item_name', 'quantity']).agg([sum]).drop(['item_price', 'choice_description', 'order_id', 'id'], axis=1)
# /var/folders/p_/0z9srqwn3g11vvrv0s9wcxs40000gn/T/ipykernel_3925/3589283754.py:2: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df5 = orders.groupby(['item_name', 'quantity']).agg([sum]).drop(['item_price', 'choice_description', 'order_id', 'id'], axis=1)

# %%
df5.groupby('item_name')['price'].sum().nlargest(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/aaronfischer/codeup-data-science/ds-libraries-exercises/Seaborn_exercises.ipynb Cell 42 line 1
# ----> <a href='vscode-notebook-cell:/Users/aaronfischer/codeup-data-science/ds-libraries-exercises/Seaborn_exercises.ipynb#Y103sZmlsZQ%3D%3D?line=0'>1</a> df5.groupby('item_name')['price'].sum().nlargest(4)
#
# TypeError: DataFrame.nlargest() missing 1 required positional argument: 'columns'

# %%
orders = orders.assign(price = orders['item_price'].str.replace('$','').astype(float))

# %%
#review = orders.groupby('item_name')['price'].sum().nlargest(4)
revenue = orders.groupby('item_name')['price'].sum().nlargest(10)

revenue
# Out:
# item_name
# Chicken Bowl           7342.73
# Chicken Burrito        5575.82
# Steak Burrito          3851.43
# Steak Bowl             2260.19
# Chips and Guacamole    2201.04
# Chicken Salad Bowl     1228.75
# Chicken Soft Tacos     1108.09
# Veggie Burrito          934.77
# Barbacoa Burrito        894.75
# Veggie Bowl             867.99
# Name: price, dtype: float64

# %%
pop_items = orders.groupby('item_name')['quantity'].sum().nlargest(10)
pop_items
# Out:
# item_name
# Chicken Bowl                    761
# Chicken Burrito                 591
# Chips and Guacamole             506
# Steak Burrito                   386
# Canned Soft Drink               351
# Chips                           230
# Steak Bowl                      221
# Bottled Water                   211
# Chips and Fresh Tomato Salsa    130
# Canned Soda                     126
# Name: quantity, dtype: int64

# %%
top_chipotle_items = pd.merge(pop_items, revenue,on = 'item_name', how = 'inner')
top_chipotle_items.head(4)
# Out:
#                      quantity    price
# item_name
# Chicken Bowl              761  7342.73
# Chicken Burrito           591  5575.82
# Chips and Guacamole       506  2201.04
# Steak Burrito             386  3851.43

# %%
top_chipotle_items.head(4).plot(kind='bar')
# Out:
# <Axes: xlabel='item_name'>

# %%
# 5.Load the sleepstudy dataset from pydataset and read it's documentation. Use seaborn to create a line chart of all the individual subject's reaction times 
# and a more prominant line showing the average change in reaction time.

sleep = data('sleepstudy')
#data('sleepstudy', show_doc=True)

# %%
sleep.head(10)
# Out:
#     Reaction  Days  Subject
# 1   249.5600     0      308
# 2   258.7047     1      308
# 3   250.8006     2      308
# 4   321.4398     3      308
# 5   356.8519     4      308
# 6   414.6901     5      308
# 7   382.2038     6      308
# 8   290.1486     7      308
# 9   430.5853     8      308
# 10  466.3535     9      308

# %%
plt.figure(figsize=(15,10))


sns.lineplot(x='Days', y='Reaction', data=sleep, hue='Subject')
sns.lineplot(x='Days', y='Reaction', data=sleep, linewidth=4, color='black')
# Out:
# <Axes: xlabel='Days', ylabel='Reaction'>

# %%
sleep_avg = sns.lineplot(x='Days',y='Reaction',data=sleep, linewidth=3, color='blue')

# %%
sleep.Subject.value_counts()
# Out:
# Subject
# 308    10
# 309    10
# 371    10
# 370    10
# 369    10
# 352    10
# 351    10
# 350    10
# 349    10
# 337    10
# 335    10
# 334    10
# 333    10
# 332    10
# 331    10
# 330    10
# 310    10
# 372    10
# Name: count, dtype: int64

# %%
sleep.groupby('Days')['Reaction'].mean().plot()
# Out:
# <Axes: xlabel='Days'>

# %%
sleep.dtypes
# Out:
# Reaction    float64
# Days          int64
# Subject       int64
# dtype: object

# %%
sleep.dtypes
# Out:
# Reaction     float64
# Days           int64
# Subject     category
# dtype: object

# %%
sleep['Subject'] = sleep.Subject.astype('category')
