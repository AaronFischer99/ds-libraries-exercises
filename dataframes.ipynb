# %%
pip install pydataset
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 1.2 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939418 sha256=5ccc683e5a4b7d92c8970b94a2b626733d34efe29f68cb313456dd454139a467
#   Stored in directory: /Users/aaronfischer/Library/Caches/pip/wheels/29/93/3f/af54c413cecaac292940342c61882d2a8848674175d0bb0889
# Successfully built pydataset
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pydataset import data

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 1. Copy the code from the lesson to create a dataframe full of student grades.

#np.random.seed(10)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
#math_grades = np.random.randint(low=60, high=100, size=len(students))
math_grades = np.linspace(60, 100, num=len(students)) #Used linespace to make math grades equally spaced
eng_grades = np.random.randint(low=60, high=100, size=len(students))
read_grades = np.random.randint(low=60, high=100, size=len(students))

student_df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': eng_grades,
                   'reading': read_grades})

# %%
student_df
# Out:
#        name  math  english  reading
# 0     Sally    73       93       89
# 1      Jane    80       90       82
# 2     Suzie    77       81       64
# 3     Billy    61       70       92
# 4       Ada    91       80       89
# 5      John    91       92       63
# 6    Thomas    75       60       97
# 7     Marie    78       66       63
# 8    Albert    62       60       96
# 9   Richard    89       75       66
# 10    Isaac    95       66       83
# 11     Alan    64       98       83

# %%
# Create a column named passing_english that indicates whether each student has a passing grade in english.

student_df.english >= 70
student_df['meet_eng_reqt'] = df.english >= 70
student_df.meet_eng_reqt.value_counts()
#student_df
# Out:
# meet_eng_reqt
# True     10
# False     2
# Name: count, dtype: int64

# %%
#. #b. Sort the english grades by the passing_english column. How are duplicates handled?
  #Duplicates are handled by the math associated math score in asc order
    
student_df.sort_values(by='meet_eng_reqt')
# Out:
#        name        math  english  reading  meet_eng_reqt
# 6    Thomas   81.818182       98       72          False
# 10    Isaac   96.363636       72       98          False
# 0     Sally   60.000000       88       75           True
# 1      Jane   63.636364       88       83           True
# 2     Suzie   67.272727       64       69           True
# 3     Billy   70.909091       86       84           True
# 4       Ada   74.545455       79       87           True
# 5      John   78.181818       71       82           True
# 7     Marie   85.454545       74       99           True
# 8    Albert   89.090909       95       77           True
# 9   Richard   92.727273       71       91           True
# 11     Alan  100.000000       79       70           True

# %%
student_df.head()
# Out:
#     name       math  english  reading  meet_eng_reqt
# 0  Sally  60.000000       88       75           True
# 1   Jane  63.636364       88       83           True
# 2  Suzie  67.272727       64       69           True
# 3  Billy  70.909091       86       84           True
# 4    Ada  74.545455       79       87           True

# %%
#C. Sort the english grades first by passing_english and then by student name. 
#All the students that are failing english should be first, 
#and within the students that are failing english they should be ordered alphabetically. 
#The same should be true for the students passing english. 
#(Hint: you can pass a list to the .sort_values method)

# %%
student_df.sort_values(by=['meet_eng_reqt', 'name'])
# Out:
#        name        math  english  reading  meet_eng_reqt
# 10    Isaac   96.363636       72       98          False
# 6    Thomas   81.818182       98       72          False
# 4       Ada   74.545455       79       87           True
# 11     Alan  100.000000       79       70           True
# 8    Albert   89.090909       95       77           True
# 3     Billy   70.909091       86       84           True
# 1      Jane   63.636364       88       83           True
# 5      John   78.181818       71       82           True
# 7     Marie   85.454545       74       99           True
# 9   Richard   92.727273       71       91           True
# 0     Sally   60.000000       88       75           True
# 2     Suzie   67.272727       64       69           True

# %%
#Sort the english grades first by passing_english, 
# and then by the actual english grade, similar to how we did in the last step.

student_df.sort_values(by=['meet_eng_reqt', 'english'])
# Out:
#        name        math  english  reading  meet_eng_reqt
# 10    Isaac   96.363636       72       98          False
# 6    Thomas   81.818182       98       72          False
# 2     Suzie   67.272727       64       69           True
# 5      John   78.181818       71       82           True
# 9   Richard   92.727273       71       91           True
# 7     Marie   85.454545       74       99           True
# 4       Ada   74.545455       79       87           True
# 11     Alan  100.000000       79       70           True
# 3     Billy   70.909091       86       84           True
# 0     Sally   60.000000       88       75           True
# 1      Jane   63.636364       88       83           True
# 8    Albert   89.090909       95       77           True

# %%
# Calculate each students overall grade and add it as a column on the dataframe. 
# The overall grade is the average of the math, english, and reading grades.

student_df['overall_grade'] = student_df()

# %%
g = student_df['math'].mean() + student_df['english'].mean() + student_df('reading').mean()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 g = student_df['math'].mean() + student_df['english'].mean() + student_df('reading').mean()
#
# TypeError: 'DataFrame' object is not callable

# %%
totals = student_df.iloc[:, 1:4].sum()
student_df['overall_grade'] = (totals / 3)
student_df
# Out:
#        name  math  english  reading  meet_eng_reqt  overall_grade
# 0     Sally    60       88       75           True            NaN
# 1      Jane    63       88       83           True            NaN
# 2     Suzie    67       64       69           True            NaN
# 3     Billy    70       86       84           True            NaN
# 4       Ada    74       79       87           True            NaN
# 5      John    78       71       82           True            NaN
# 6    Thomas    81       98       72          False            NaN
# 7     Marie    85       74       99           True            NaN
# 8    Albert    89       95       77           True            NaN
# 9   Richard    92       71       91           True            NaN
# 10    Isaac    96       72       98          False            NaN
# 11     Alan   100       79       70           True            NaN

# %%
student_df.drop('overall_grade', axis=1)
# Out:
#        name  math  english  reading  meet_eng_reqt
# 0     Sally    60       88       75           True
# 1      Jane    63       88       83           True
# 2     Suzie    67       64       69           True
# 3     Billy    70       86       84           True
# 4       Ada    74       79       87           True
# 5      John    78       71       82           True
# 6    Thomas    81       98       72          False
# 7     Marie    85       74       99           True
# 8    Albert    89       95       77           True
# 9   Richard    92       71       91           True
# 10    Isaac    96       72       98          False
# 11     Alan   100       79       70           True

# %%
totals = student_df.iloc[:, 1:4].sum(axis=1)
student_df['overall_average'] = (totals / 3).astype(int)
student_df
# Out:
#        name  math  english  reading  meet_eng_reqt  overall_average
# 0     Sally    60       88       75           True               74
# 1      Jane    63       88       83           True               78
# 2     Suzie    67       64       69           True               66
# 3     Billy    70       86       84           True               80
# 4       Ada    74       79       87           True               80
# 5      John    78       71       82           True               77
# 6    Thomas    81       98       72          False               83
# 7     Marie    85       74       99           True               86
# 8    Albert    89       95       77           True               87
# 9   Richard    92       71       91           True               84
# 10    Isaac    96       72       98          False               88
# 11     Alan   100       79       70           True               83

# %% [markdown]
# ### 2. Load the mpg dataset. Read the documentation for the dataset and use it for the following questions:

# %%
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
mpg_df = data('mpg')
mpg_df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
# How many rows and columns are there?
mpg_df.shape
# Out:
# (234, 11)

# %%
#What are the data types of each column?
mpg_df.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %%
# Summarize the dataframe with .info and .describe
mpg_df.describe(), mpg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB
# (            displ         year         cyl         cty         hwy
#  count  234.000000   234.000000  234.000000  234.000000  234.000000
#  mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# ...

# %%
#Rename the cty column to city.

mpg_df.rename(columns={"cty": "city"}, inplace=True)

# %%
# Rename the hwy column to highway.

mpg_df.rename(columns={"hwy": "highway"}, inplace=True)

# %%
# Do any cars have better city mileage than highway mileage?

None
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %%
mpg_df['diff'] = np.subtract(mpg_df['city'], mpg_df['highway'])

# %%
mpg_df.sort
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  diff
# 1    compact   -11
# ...

# %%
# Which car (or cars) has the highest mileage difference?
mileage_diff = mpg_df.loc[mpg_df['diff'] == -12]
mileage_diff
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  city  highway  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f    24       36
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f    29       41
#
#     fl       class  diff
# 107  c  subcompact   -12
# 223  d  subcompact   -12

# %%
# Which compact class car has the lowest highway mileage? The best?

a = mpg_df.loc[mpg_df['highway'] & (mpg_df['class'] == 'compact')]
a.min()
#volkswagen	jetta	2.8	1999	6	auto(l4)	f	16	23	r	compact
# Out:
# manufacturer        audi
# model                 a4
# displ                1.8
# year                1999
# cyl                    4
# trans           auto(av)
# drv                    4
# city                  15
# highway               23
# fl                     p
# class            compact
# diff                 -11
# dtype: object

# %%
average_mileage = mpg_df.iloc[:, 7:9].mean(axis=1)
mpg_df['average_mileage'] = average_mileage 
#average_mileage

# %%
#Create a column named average_mileage that is the mean of the city and highway mileage.

# %%
mpg_df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  diff  average_mileage
# ...

# %%
# Which dodge car has the best average mileage? The worst?

mpg_df_dodge = mpg_df.sort_values(by=['average_mileage', 'manufacturer'], ascending=True)
#df_sorted = df.sort_values(by=['Age', 'Salary'], ascending=[True, False])

mpg_df_dodge
#Best = dodge dakota pickup year 2008
#Worst = volkswagon new beetle year 1999
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  city  \
# 55         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 60         dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 66         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 70         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
# 127         jeep   grand cherokee 4wd    4.7  2008    8    auto(l5)   4     9
# ..           ...                  ...    ...   ...  ...         ...  ..   ...
# 198       toyota              corolla    1.8  2008    4    auto(l4)   f    26
# 197       toyota              corolla    1.8  2008    4  manual(m5)   f    28
# 223   volkswagen           new beetle    1.9  1999    4    auto(l4)   f    29
# 213   volkswagen                jetta    1.9  1999    4  manual(m5)   f    33
# 222   volkswagen           new beetle    1.9  1999    4  manual(m5)   f    35
#
# ...

# %%
dodge_series = mpg_df.manufacturer == 'dodge'
dodges = mpg_df[dodge_series]
dodges.sort_values(by='average_mileage').tail(1)
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
#
#    fl    class  diff  average_mileage
# 38  r  minivan    -6             21.0

# %%
dodge_series = mpg_df.manufacturer == 'dodge'
dodges = mpg_df[dodge_series]
dodges.sort_values(by='average_mileage').head(1)
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
#
#     highway fl   class  diff  average_mileage
# 70       12  e  pickup    -3             10.5

# %%
dodge_series = mpg_df.loc[mpg_df.manufacturer == 'dodge']
dodge_series.min()
# Out:
# manufacturer             dodge
# model              caravan 2wd
# displ                      2.4
# year                      1999
# cyl                          4
# trans                 auto(l3)
# drv                          4
# city                         9
# highway                     12
# fl                           e
# class                  minivan
# diff                        -7
# average_mileage           10.5
# dtype: object

# %% [markdown]
# ### 3. Load the Mammals dataset. Read the documentation for it, and use the data to answer these questions:

# %%
data('Mammals', show_doc=True)
animals = data('Mammals')
animals.head()
# Out:
# Mammals
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Garland(1983) Data on Running Speed of Mammals
#
# ### Description
#
# Observations on the maximal running speed of mammal species and their body
# mass.
#
# ### Usage
#
#     data(Mammals)
#
# ### Format
#
# A data frame with 107 observations on the following 4 variables.
#
# weight
#
# Body mass in Kg for "typical adult sizes"
#
# speed
#
# Maximal running speed (fastest sprint velocity on record)
#
# hoppers
#
# logical variable indicating animals that ambulate by hopping, e.g. kangaroos
#
# specials
#
# logical variable indicating special animals with "lifestyles in which speed
# does not figure as an important factor": Hippopotamus, raccoon (Procyon),
# badger (Meles), coati (Nasua), skunk (Mephitis), man (Homo), porcupine
# (Erithizon), oppossum (didelphis), and sloth (Bradypus)
#
# ### Details
#
# ...

# %%
#1. How many rows and columns are there?
animals.shape
# Out:
# (107, 4)

# %%
#2. What are the data types?
animals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
#3. Summarize the dataframe with .info and .describe
animals.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %%
# 4. What is the the weight of the fastest animal?
55 pounds
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False

# %%
#5. What is the overal percentage of specials?
total_specials = animals.specials.sum()

total_mammals = len(animals)

overall_percentage_of_specials = round(total_specials / total_mammals * 100,2)

print(f'{overall_percentage_of_specials}%')
# Out:
# 9.35%

# %%
#6. How many animals are hoppers that are above the median speed? What percentage is this?
hoppers = animals.hoppers.sum()

speed = animals.speed.median()

# %%
hoppers, speed
# Out:
# (11, 48.0)

# %%
hoppers
# Out:
# 11

# %%
animal_speed = animals[animals.speed > 48]

# %%
animal_speed.hoppers.value_counts(), 
#animal_speed.hoppers.value_counts(True) * 100   #percentage of TRue outcomes
# Out:
# (hoppers
#  False    46
#  True      7
#  Name: count, dtype: int64,)

# %%
animal_speed.hoppers.value_counts(True) * 100   #percentage of TRue outcomes
# Out:
# hoppers
# False    86.792453
# True     13.207547
# Name: proportion, dtype: float64
